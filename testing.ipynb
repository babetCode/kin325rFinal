# %%
from ezc3d import c3d
import numpy as np
import pandas as pd
import math

myc3d = c3d('c3d_files/Dynamic1.c3d')

analog_data = myc3d['data']['analogs']
analogs = analog_data[0, :, :]
analog_labels = myc3d['parameters']['ANALOG']['LABELS']['value']
analog_df = pd.DataFrame(data=analogs, index=analog_labels)
analog_df
# Out:
#                                         0             1             2      \
# CH1                                  0.000000      0.000000      0.000000
# CH1_ACC_X                            0.000000      0.000000      0.000000
# CH1_ACC_Y                            0.000000      0.000000      0.000000
# CH1_ACC_Z                            0.000000      0.000000      0.000000
# CH1_GYRO_X                           0.000000      0.000000      0.000000
# CH1_GYRO_Y                           0.000000      0.000000      0.000000
# CH1_GYRO_Z                           0.000000      0.000000      0.000000
# CH1_MAG_X                            0.000000      0.000000      0.000000
# CH1_MAG_Y                            0.000000      0.000000      0.000000
# CH1_MAG_Z                            0.000000      0.000000      0.000000
# CH2                                  0.000000      0.000000      0.000000
# CH2_ACC_X                            0.000000      0.000000      0.000000
# ...

# %%
point_data = myc3d['data']['analogs']
points = analog_data[0, :, :]
point_labels = myc3d['parameters']['POINT']['LABELS']['value']
points
point_df = pd.DataFrame(data=points)
point_df
# Out:
# array([[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#         -8.51208589e-06, -6.89044188e-06, -6.93161867e-06],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#         -4.10156250e-02, -4.10156250e-02, -4.10156250e-02],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#         -9.79980528e-01, -9.79980528e-01, -9.79980528e-01],
#        ...,
#        [ 4.06484375e+04,  4.06485586e+04,  4.08906250e+04, ...,
#          4.07480469e+04,  4.07480469e+04,  4.07480469e+04],
#        [ 2.91396484e+04,  2.91395684e+04,  2.89785156e+04, ...,
#          2.93701172e+04,  2.93701172e+04,  2.93701172e+04],
#        [-1.14462891e+04, -1.14462451e+04, -1.13579102e+04, ...,
#         -1.13754883e+04, -1.13754883e+04, -1.13754883e+04]])
